# %% [markdown]
# <h1 dir=rtl align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مقدمه‌ای بر شبکه عصبی
# </font>
# </h1>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#      در این تمرین قصد داریم ساختار پرسپترون و الگوریتم آموزش آن را پیاده‌سازی کنیم. کدنویسی در این سطح به شما کمک خواهد کرد که به شکل عملی درک عمیق‌تری از نحوه‌ی کار این مدل پیدا کنید و در آینده نیز هنگام مواجه با مدل‌های مختلف شبکه‌های عصبی قادر به تحلیل آسان‌تر ساختار آن‌ها باشید.
# </font>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# <span style="color:orange"><b>نکته:</b></span>
# در این تمرین شما تنها مجاز هستید از کتاب خانه‌هایی که در فایل <code>import</code>  شده‌اند، استفاده کنید.
# </font>
# </p>

# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# ابتدا با استفاده از تابع زیر یک مجموعه‌داده‌ی مصنوعی دو بعدی را تولید می‌کنیم . این مجموعه، یک مجموعه‌داده‌ی دو کلاسه است.
# </font>

# %%
def load_datasets():
    X1, y1 = sklearn.datasets.make_gaussian_quantiles(
      cov=2.0, n_samples=200, n_features=2, n_classes=2, random_state=1)
    X2, y2 = sklearn.datasets.make_gaussian_quantiles(
      mean=(3, 3), cov=1.5, n_samples=300, n_features=2, n_classes=2, random_state=1)

    X = np.concatenate((X1, X2))
    y = np.concatenate((y1, -y2 + 1))

    return X , y

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# خروجی تابع <code>load_datasets</code> شامل <code>X</code>, <code>y</code> است که
# <code>X</code> آرایه‌ی نامپای با اندازه‌ی ۲ ستون در ۵۰۰ سطر است
# و <code>y</code> یک بردار ۵۰۰ تایی ۰ و ۱ است، که نمایانگر برچسب هر کدام از نقاط موجود در <code>X</code> است.
# </font>

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مصورسازی مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# مجموعه‌داده را با استفاده از کتابخانه‌ی <code>matplotlib</code> رسم کنید. نقاط با برچسب ۱ را با رنگ آبی و نقاط با برچسب ۰ را با رنگ قرمز مشخص نمایید.
# </font>

# %%
X , y = load_datasets()
# TO-DO (Data Visualization)

plt.figure(figsize=(8,6))

# Get indices of examples for each class
class_zero = np.where(y == 0)
class_one = np.where(y == 1)

# Plot points
plt.scatter(X[class_zero, 0], X[class_zero, 1], color='red', label='Class 0')
plt.scatter(X[class_one, 0], X[class_one, 1], color='blue', label='Class 1')

plt.title('Data Visualization')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()

plt.show()

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل پایه
# </font>
# </h2>

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# قبل از ساختن یک شبکه عصبی، ابتدا ببینیم که الگوریتم <code>LogisticRegressionCV</code> چگونه این نقاط را دسته بندی می‌کند. همان‌طور که می‌دانیم این مدل، یک مدل خطی است.
# </font>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# برای این کار از کتابخانه‌ی <code>scikit-learn</code> کمک بگیرید.
# </font>

# %%
from sklearn.linear_model import LogisticRegressionCV

clf = LogisticRegressionCV(cv=5, random_state=0) # TO-DO (Try LogisticRegressionCV)

clf.fit(X, y)
# Out:
# LogisticRegressionCV(cv=5, random_state=0)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# تابع <code>plot_decision_boundary</code> زیر به شما کمک می‌کند تا محدوده‌ی دسته‌بندی مدل را ترسیم کنید.
# </font>

# %%
from sklearn.inspection import DecisionBoundaryDisplay

def plot_decision_boundary(model, X, y):
    plt.figure(figsize=(10, 5))

    ax = plt.subplot(121)
    disp = DecisionBoundaryDisplay.from_estimator(
        model,
        X,
        cmap=plt.cm.Paired,
        response_method="predict",
        ax=ax,
        xlabel="x",
        ylabel="y")

    x_min, x_max = disp.xx0.min(), disp.xx0.max()
    y_min, y_max = disp.xx1.min(), disp.xx1.max()

    plt.axis("tight")

    for i, n, c in zip(range(2), "AB", "br"):
      idx = np.where(y == i)
      plt.scatter(
          X[idx, 0],
          X[idx, 1],
          c=c,
          cmap=plt.cm.Paired,
          s=20,
          edgecolor="k",
          label="Class %s" % n)
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)
    plt.legend(loc="upper right")
    plt.title("Decision Boundary")

# %%
plot_decision_boundary(clf, X, y)
plt.title("Logistic Regression");
# Out:
# <ipython-input-5-4dc01d689edf>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# شبکه‌ی عصبی ساده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# همان‌طور که در قسمت قبل قابل مشاهده است این مجموعه نقاط به‌صورتی نیستند که بتوانیم با یک مدل خطی آن‌ها را از یکدیگر تفکیک کنیم، در نتیجه Logistic Regression عملکرد خوبی ندارد. پس در ادامه یک شبکه عصبی ساده می‌نویسیم و داده‌ها را با آن دسته‌بندی می‌کنیم.
# </font>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# تصویری از مدلی که باید پیاده سازی کنیم را در زیر می‌بینیم.
# </font>
# </p>
#
# <center>
# <img src="model_1.jpg">
# </center>

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# واضح است که ورودی مدل یک دوتایی است (زیرا ورودی آن مختصات یک نقطه در فضای دو بعدی است).برای شبکه عصبی دو لایه در نظر می‌گیریم که لایه‌ی اول شامل ۴ نورون و لایه‌ی دوم ۱ نورون دارد.
# تابع فعال‌ساز لایه‌ی اول <code>tanh</code>   و تابع فعال‌ساز لایه‌ی دوم <code>sigmoid</code> است.
# خروجی مدل نیز یک عدد است (مقدار ۰ یا ۱).
# </font>

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# تنظیم مشخصات کلی شبکه
# </font>
# </h3>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# پس در ابتدا متغیرهایی تعریف کنید و تعداد ورودی، تعداد خروجی و تعداد نورون‌های لایه‌ی اول را مشخص نمایید.
# </font>
# </p>

# %%
n_x = 2 # To-Do (Number of input)
n_h = 4 # To-Do (Number of neurons in hidden layer)
n_y = 1 # To-Do (Number of output neurons)

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مقداردهی اولیه پارامترها (وزن‌ها)
# </font>
# </h3>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# اکنون تابع زیر را تکمیل کنید. این تابع متغیرهای تنظیم‌شده در سلول بالا را دریافت می‌کند و مقادیر اولیه  <code>W1</code>، <code>b1</code>، <code>W2</code> و <code>b2</code> را بر می‌گرداند. وزن‌ها را به‌صورت تصادفی و با استفاده از تابع توزیع گوسی مقداردهی کنید (واریانس این توزیع <code>0.01</code> باشد)  و مقدار اولیه <code>b</code> را <code>0</code> قرار دهید.
# </font>
# </p>
# <details dir="rtl" style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <summary dir="rtl" style="color:orange"><b>راهنمایی: ابعاد خروجی تابع</b></summary>
# متغیر های خروجی باید ابعادی به شکل زیر داشته باشند:
# <p  style="direction: rtl; text-align: center; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# <code>
# W1.shape = (4, 2)
# </code>
# <br>
# <code>
# b1.shape = (4, 1)
# </code>
# <br>
# <code>
# W2.shape = (1, 4)
# </code>
# <br>
# <code>
# b2.shape = (1, 1)
# </code>
# </font>
# </details>

# %%
def initialize_parameters(n_x, n_h, n_y):
    # Initialize W1, b1, W2, b2
    np.random.seed(2)

    W1 = np.random.randn(n_h, n_x) * 0.01 # To-Do
    b1 = np.zeros((n_h, 1)) # To-Do
    W2 = np.random.randn(n_y, n_h) * 0.01 # To-Do
    b2 = np.zeros((n_y, 1)) # To-Do

    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}

    return parameters

# %%
parameters = initialize_parameters(n_x, n_h, n_y)

# printing the parameters
for key, value in parameters.items():
    print(key, value.shape)
    print(value)
    print('-' * 60)
# Out:
# W1 (4, 2)
# [[-0.00416758 -0.00056267]
#  [-0.02136196  0.01640271]
#  [-0.01793436 -0.00841747]
#  [ 0.00502881 -0.01245288]]
# ------------------------------------------------------------
# b1 (4, 1)
# [[0.]
#  [0.]
#  [0.]
#  [0.]]
# ------------------------------------------------------------
# W2 (1, 4)
# [[-0.01057952 -0.00909008  0.00551454  0.02292208]]
# ------------------------------------------------------------
# b2 (1, 1)
# [[0.]]
# ------------------------------------------------------------

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# انتشار رو به جلو (Forward Propagation)
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# اکنون نیاز است گذر رو به جلو را در تابع <code>forward_propagation</code> پیاده‌سازی کنید. برای راحتی شما دوباره فرمول‌ها را در زیر آورده‌ایم. اما می‌توانید از تصویر مدل نیز استفاده کنید. همچنین برای این‌که کد تمیزتری داشته باشید، بهتر است تابع سیگموید را در یک تابع جدا پیاده‌سازی کنید.
# </font>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# فراموش نکنید که تابع علاوه بر مقدار <code>A2</code> باید بقیه مقادیر را نیز برگرداند. (به این مقادیر در فاز <code>backward_propagation</code> نیازمندیم)
# </font>
# </p>
#
#
# $$z^{[1] (i)} =  W^{[1]} x^{(i)} + b^{[1]}$$
# $$a^{[1] (i)} = \tanh(z^{[1] (i)})$$
# $$z^{[2] (i)} = W^{[2]} a^{[1] (i)} + b^{[2]}$$
# $$\hat{y}^{(i)} = a^{[2] (i)} = \sigma(z^{ [2] (i)})$$
# $$ \sigma (x) =  \frac{\mathrm{1} }{\mathrm{1} + e^{-x} }  $$

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z)) # To-Do (Sigmoid function)

# %%
# make sure that the function works correctly: should output array([[0.5]])
sigmoid(np.array([[0.]]))
# Out:
# array([[0.5]])

# %%
def forward_propagation(X, parameters):

    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']

    Z1 = np.dot(W1, X.T) + b1 # To-Do (Compute Z1)
    A1 = np.tanh(Z1) # To-Do (Compute A1)
    Z2 = np.dot(W2, A1) + b2 # To-Do (Compute Z2)
    A2 = sigmoid(Z2) # To-Do (Compute A2)

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}

    return A2, cache

# %%
A2, cache = forward_propagation(X, parameters)

for key, value in cache.items():
    print(key, value.shape)
# Out:
# Z1 (4, 500)
# A1 (4, 500)
# Z2 (1, 500)
# A2 (1, 500)

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# تابع هزینه (Cost Function)
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# حال نیاز است تابع هزینه را پیاده‌سازی کنید. تابع هزینه‌ی مورد نظر،  تابع cross entropy است که به شکل زیر فرموله می‌شود.
# </font>
# </p>
#
# $$J = - \frac{1}{m} \sum\limits_{i = 0}^{m} \large\left(\small y^{(i)}\log\left(a^{[2] (i)}\right) + (1-y^{(i)})\log\left(1- a^{[2] (i)}\right)  \large  \right)$$

# %%
def compute_cost(A2, Y, parameters):
    m = Y.shape[0]
    Y = y.reshape(-1,1)
    cost = -1/m * (np.dot(Y.T ,np.log(A2.T)) + np.dot((1-Y.T) , np.log(1-A2.T))) # To-Do (Compute cross-entropy cost)
    return cost[0,0]

# %%
print("cost = " + str(compute_cost(A2, y, parameters)))
# Out:
# cost = 0.6931432417183269

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# انتشار رو به عقب یا پس‌انتشار (‌Backpropagation)
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# اکنون باید عملیات پس‌انتشار را با توجه به گرادیان‌های محاسبه‌شده در تابع <code>backward_propagation</code> پیاده سازی کنید.
# </font>
# </p>
#
# $$dz^{[2]} =  a^{[2]} - y$$
# $$dW^{[2]} = dz^{[2]}a^{[1]^{T}}$$
# $$db^{[2]} = dz^{[2]}$$
# $$dz^{[1]} = W^{[2]^{T}}dz^{[2]}* g^{[1]'}(z^{[1]})$$
# $$dW^{[1]} = dz^{[1]}X$$
# $$db^{[1]} = dz^{[1]}$$

# %%
def backward_propagation(parameters, cache, X, Y):

    m = X.shape[0]

    W2 = parameters['W2']

    A1 = cache['A1']
    A2 = cache['A2']

    #Y = y.reshape(1, -1)

    dZ2 = A2 - Y

    dW2 = 1 / m * np.dot(dZ2, A1.T) # To-Do (Compute dW2)
    db2 = 1 / m * np.sum(dZ2, axis=1, keepdims=True) # To-Do (Compute db2)

    dZ1 =  np.dot(W2.T, dZ2) * (1 - np.power(A1, 2))

    dW1 = 1 / m * np.dot(dZ1, X) # To-Do (Compute dW1)
    db1 = 1 / m * np.sum(dZ1, axis=1, keepdims=True) # To-Do (Compute db1)

    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}

    return grads

# %%
grads = backward_propagation(parameters, cache, X, y)

for key, value in grads.items():
    print(key, value.shape)
    print(value)
    print('-' * 60)
# Out:
# dW1 (4, 2)
# [[-9.13405384e-05 -1.36229314e-04]
#  [-7.07834411e-05 -1.11729584e-04]
#  [ 3.90432821e-05  6.44295939e-05]
#  [ 1.96049304e-04  2.85632591e-04]]
# ------------------------------------------------------------
# db1 (4, 1)
# [[ 1.12314108e-06]
#  [ 1.09914488e-06]
#  [-1.29164286e-06]
#  [-2.79347227e-06]]
# ------------------------------------------------------------
# dW2 (1, 4)
# [[-4.34223960e-05  2.90597192e-05 -2.51502292e-04 -1.15410349e-04]]
# ------------------------------------------------------------
# db2 (1, 1)
# [[-0.00010194]]
# ------------------------------------------------------------

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# به‌روزرسانی پارامترها (وزن‌ها)
# </font>
# </h3>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# پس از محاسبه‌ی گرادیان‌ها می‌توانیم پارامترهای شبکه را آپدیت کنیم. برای این کار طبق فرمول‌های زیر تابع <code>update_parameters</code> را پیاده‌سازی کنید.
# </font>
# </p>
#
# $$W^{[1]} = W^{[1]} - learningRate * dW^{[1]}$$
# $$b^{[1]} = b^{[1]} - learningRate * db^{[1]}$$
# $$W^{[2]} = W^{[2]} - learningRate * dW^{[2]}$$
# $$b^{[2]} = b^{[2]} - learningRate * db^{[2]}$$

# %%
def update_parameters(parameters, grads, learning_rate):

    W1 = parameters['W1'] # To-Do (Update W1)
    b1 = parameters['b1'] # To-Do (Update b1)
    W2 = parameters['W2'] # To-Do (Update W2)
    b2 = parameters['b2'] # To-Do (Update b2)

    dW1 = grads['dW1']
    db1 = grads['db1']
    dW2 = grads['dW2']
    db2 = grads['db2']

    W1 = W1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    W2 = W2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2

    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}

    return parameters

# %%
parameters = update_parameters(parameters, grads, 1.2)

for key, value in parameters.items():
    print(key, value.shape)
    print(value)
    print('-' * 60)
# Out:
# W1 (4, 2)
# [[-0.00405797 -0.00039919]
#  [-0.02127702  0.01653678]
#  [-0.01798121 -0.00849479]
#  [ 0.00479356 -0.01279564]]
# ------------------------------------------------------------
# b1 (4, 1)
# [[-1.34776930e-06]
#  [-1.31897385e-06]
#  [ 1.54997143e-06]
#  [ 3.35216673e-06]]
# ------------------------------------------------------------
# W2 (1, 4)
# [[-0.01052742 -0.00912495  0.00581634  0.02306057]]
# ------------------------------------------------------------
# b2 (1, 1)
# [[0.00012233]]
# ------------------------------------------------------------

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# شبکه‌ی عصبی نهایی و حلقه‌ی آموزش
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# حال که تمام اجزای مورد نیاز شبکه‌ی عصبی خود را پیاده کردید می‌توانید آن‌ها در یک تابع کلی کنار هم قرار داده و حلقه‌ی آموزش را بسازید. مدل شبکه عصبی خود را با استفاده از توابع قسمت‌های قبل در تابع <code>nn_model</code> پیاده‌سازی کنید.
# </font>
# </p>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# روند این تابع باید به‌صورت زیر باشد:
# <ul dir=rtl >
# <li dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# تابع مقداردهی اولیه فراخوانی شود تا <code>W1</code>، <code>b1</code>، <code>W2</code> و <code>b2</code>  مقداردهی اولیه شوند.
# </li>
# <li dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# در یک حلقه به تعداد <code>num_iterations</code> بار، مراحل زیر تکرار شود:
# </li>
# <li dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# انتشار رو به جلو به کمک تابع <code>forward_propagation</code> انجام شود.
# </li>
# <li dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# مقدار تابع هزینه محاسبه شود.
# </li>
# <li dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# مقدار گرادیان به کمک پس‌انتشار یعنی تابع <code>backward_propagation</code> محاسبه شود.
# </li>
# <li dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# پارامترها به کمک تابع <code>update_parameters</code> به‌روزرسانی شوند.
# </li>
# </ul>
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# پیشنهاد می‌شود بعد از یک تعداد دور (مثلاُ ۱۰۰۰ دور) میزان هزینه را خروجی دهید.
# </font>
# </p>

# %%
def nn_model(X, Y, learning_rate, num_iterations = 10000):

    # Set the network details like the number of input, hidden and output neurons
    n_x = X.shape[1]
    n_y = 1

    # Initialize parameters
    parameters = initialize_parameters(n_x, n_h, n_y)

    # Loop (gradient descent)
    for i in range(0, num_iterations):

            # Forward propagation
            A2, cache = forward_propagation(X, parameters)

            # Compute cost
            cost = compute_cost(A2, Y, parameters)

            # Backward propagation
            grads = backward_propagation(parameters, cache, X, Y)

            # Update parameters (using gradient descent)
            parameters = update_parameters(parameters, grads, learning_rate)

            # Print the cost every 1000 iterations
            if i % 1000 == 0:
              print('Cost after iteration %i: %f' %(i, cost))

    return parameters

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌بینی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در انتها باید تابع <code>predict</code> را پیاده‌سازی کنیم. این تابع خروجی شبکه را به‌صورت زیر پیش‌بینی کند:
# </font>
# </p>
#
# $$ y^{(i)}_{prediction} = \begin{cases} 1 & \text{if } a^{[2](i)} > 0.5 \\ 0 & \text{otherwise } \end{cases} $$

# %%
def predict(parameters, X):

    A2, cache = forward_propagation(X, parameters)
    predictions = (A2 > 0.5) # To-Do (Compute predictions)

    return predictions

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آزمایش
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# اکنون با کد زیر مدل را <code>150000</code> بار با نرخ یادگیری <code>0.1</code> آموزش دهید.
# </font>

# %%
parameters = nn_model(X, y, learning_rate = 0.1 , num_iterations = 150000)
# Out:
# Cost after iteration 0: 0.693143
# Cost after iteration 1000: 0.693105
# Cost after iteration 2000: 0.693085
# Cost after iteration 3000: 0.693077
# Cost after iteration 4000: 0.693073
# Cost after iteration 5000: 0.693070
# Cost after iteration 6000: 0.693068
# Cost after iteration 7000: 0.693066
# Cost after iteration 8000: 0.693065
# Cost after iteration 9000: 0.693064
# Cost after iteration 10000: 0.693063
# Cost after iteration 11000: 0.693062
# Cost after iteration 12000: 0.693062
# Cost after iteration 13000: 0.693061
# Cost after iteration 14000: 0.693061
# Cost after iteration 15000: 0.693060
# Cost after iteration 16000: 0.693060
# Cost after iteration 17000: 0.693059
# Cost after iteration 18000: 0.693059
# Cost after iteration 19000: 0.693059
# Cost after iteration 20000: 0.693058
# Cost after iteration 21000: 0.693058
# Cost after iteration 22000: 0.693058
# Cost after iteration 23000: 0.693057
# Cost after iteration 24000: 0.693057
# Cost after iteration 25000: 0.693057
# Cost after iteration 26000: 0.693057
# Cost after iteration 27000: 0.693056
# Cost after iteration 28000: 0.693056
# Cost after iteration 29000: 0.693056
# Cost after iteration 30000: 0.693056
# Cost after iteration 31000: 0.693056
# Cost after iteration 32000: 0.693056
# Cost after iteration 33000: 0.693055
# Cost after iteration 34000: 0.693055
# Cost after iteration 35000: 0.693055
# Cost after iteration 36000: 0.693055
# Cost after iteration 37000: 0.693055
# Cost after iteration 38000: 0.693055
# Cost after iteration 39000: 0.693054
# Cost after iteration 40000: 0.693054
# Cost after iteration 41000: 0.693054
# Cost after iteration 42000: 0.693054
# Cost after iteration 43000: 0.693054
# Cost after iteration 44000: 0.693054
# Cost after iteration 45000: 0.693054
# Cost after iteration 46000: 0.693053
# Cost after iteration 47000: 0.693053
# Cost after iteration 48000: 0.693053
# Cost after iteration 49000: 0.693053
# Cost after iteration 50000: 0.693053
# Cost after iteration 51000: 0.693053
# Cost after iteration 52000: 0.693053
# Cost after iteration 53000: 0.693053
# Cost after iteration 54000: 0.693052
# Cost after iteration 55000: 0.693052
# Cost after iteration 56000: 0.693052
# Cost after iteration 57000: 0.693052
# Cost after iteration 58000: 0.693052
# Cost after iteration 59000: 0.693052
# Cost after iteration 60000: 0.693052
# Cost after iteration 61000: 0.693052
# Cost after iteration 62000: 0.693051
# Cost after iteration 63000: 0.693051
# Cost after iteration 64000: 0.693051
# Cost after iteration 65000: 0.693051
# Cost after iteration 66000: 0.693051
# Cost after iteration 67000: 0.693051
# Cost after iteration 68000: 0.693051
# Cost after iteration 69000: 0.693050
# Cost after iteration 70000: 0.693050
# Cost after iteration 71000: 0.693050
# Cost after iteration 72000: 0.693050
# Cost after iteration 73000: 0.693050
# Cost after iteration 74000: 0.693049
# Cost after iteration 75000: 0.693049
# Cost after iteration 76000: 0.693049
# Cost after iteration 77000: 0.693049
# Cost after iteration 78000: 0.693048
# Cost after iteration 79000: 0.693048
# Cost after iteration 80000: 0.693047
# Cost after iteration 81000: 0.693047
# Cost after iteration 82000: 0.693027
# Cost after iteration 83000: 0.675395
# Cost after iteration 84000: 0.551293
# Cost after iteration 85000: 0.527363
# Cost after iteration 86000: 0.509064
# Cost after iteration 87000: 0.358039
# Cost after iteration 88000: 0.333271
# Cost after iteration 89000: 0.320129
# Cost after iteration 90000: 0.314363
# Cost after iteration 91000: 0.311270
# Cost after iteration 92000: 0.309396
# Cost after iteration 93000: 0.308163
# Cost after iteration 94000: 0.307305
# Cost after iteration 95000: 0.306680
# Cost after iteration 96000: 0.306209
# Cost after iteration 97000: 0.305845
# Cost after iteration 98000: 0.305554
# Cost after iteration 99000: 0.305317
# Cost after iteration 100000: 0.305119
# Cost after iteration 101000: 0.304950
# Cost after iteration 102000: 0.304803
# Cost after iteration 103000: 0.304672
# Cost after iteration 104000: 0.304555
# Cost after iteration 105000: 0.304447
# Cost after iteration 106000: 0.304348
# Cost after iteration 107000: 0.304256
# Cost after iteration 108000: 0.304169
# Cost after iteration 109000: 0.304086
# Cost after iteration 110000: 0.304008
# Cost after iteration 111000: 0.303933
# Cost after iteration 112000: 0.303861
# Cost after iteration 113000: 0.303791
# Cost after iteration 114000: 0.303723
# Cost after iteration 115000: 0.303658
# Cost after iteration 116000: 0.303593
# Cost after iteration 117000: 0.303530
# Cost after iteration 118000: 0.303468
# Cost after iteration 119000: 0.303406
# Cost after iteration 120000: 0.303344
# Cost after iteration 121000: 0.303280
# Cost after iteration 122000: 0.303209
# Cost after iteration 123000: 0.303124
# Cost after iteration 124000: 0.302994
# Cost after iteration 125000: 0.302749
# Cost after iteration 126000: 0.302274
# Cost after iteration 127000: 0.301458
# Cost after iteration 128000: 0.298759
# Cost after iteration 129000: 0.289517
# Cost after iteration 130000: 0.286768
# Cost after iteration 131000: 0.286411
# Cost after iteration 132000: 0.286362
# Cost after iteration 133000: 0.286313
# Cost after iteration 134000: 0.286216
# Cost after iteration 135000: 0.286086
# Cost after iteration 136000: 0.285942
# Cost after iteration 137000: 0.285795
# Cost after iteration 138000: 0.285650
# Cost after iteration 139000: 0.285509
# Cost after iteration 140000: 0.285374
# Cost after iteration 141000: 0.285245
# Cost after iteration 142000: 0.285121
# Cost after iteration 143000: 0.285001
# Cost after iteration 144000: 0.284887
# Cost after iteration 145000: 0.284777
# Cost after iteration 146000: 0.284672
# Cost after iteration 147000: 0.284571
# Cost after iteration 148000: 0.284475
# Cost after iteration 149000: 0.284382

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# حال دوباره محدوده دسته‌بندی مدل شبکه عصبی را رسم کنید و تفاوت‌ها و دقت یادگیری مدل شبکه عصبی را ببینید.
# </font>

# %%
def plot_decision_boundary_for_nn(model, X, y):

    x_min, x_max = X[0, :].min() - 1, X[0, :].max() + 1
    y_min, y_max = X[1, :].min() - 1, X[1, :].max() + 1
    h = 0.01

    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    Z = model(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[0, :], X[1, :], c=y, cmap=plt.cm.Spectral)

# %%
plot_decision_boundary_for_nn(lambda x: predict(parameters, x), X.T, y.T)
plt.title("Decision Boundary for NN ");
